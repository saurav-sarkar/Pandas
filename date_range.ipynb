# %%
import pandas as pd
df = pd.read_csv("aapl1.csv",index_col=None)
df.head(5)
# Out:
#          Open        High         Low       Close   Adj Close    Volume
# 0  203.169998  204.490005  200.649994  201.550003  199.172989  27316700
# 1  201.410004  203.130005  201.360001  202.729996  200.339050  16935200
# 2  203.279999  204.440002  202.690002  204.410004  201.999237  11362000
# 3  203.350006  205.080002  202.899994  204.229996  201.821350  17265500
# 4  200.809998  201.399994  198.410004  200.020004  197.661011  25338600

# %%
rng = pd.date_range(start="1/07/2019",end="12/24/2019",freq='B')
rng
# Out:
# DatetimeIndex(['2019-01-07', '2019-01-08', '2019-01-09', '2019-01-10',
#                '2019-01-11', '2019-01-14', '2019-01-15', '2019-01-16',
#                '2019-01-17', '2019-01-18',
#                ...
#                '2019-12-11', '2019-12-12', '2019-12-13', '2019-12-16',
#                '2019-12-17', '2019-12-18', '2019-12-19', '2019-12-20',
#                '2019-12-23', '2019-12-24'],
#               dtype='datetime64[ns]', length=252, freq='B')

# %%
df.set_index(rng,inplace=True)
df
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-01-07  203.169998  204.490005  200.649994  201.550003  199.172989
# 2019-01-08  201.410004  203.130005  201.360001  202.729996  200.339050
# 2019-01-09  203.279999  204.440002  202.690002  204.410004  201.999237
# 2019-01-10  203.350006  205.080002  202.899994  204.229996  201.821350
# 2019-01-11  200.809998  201.399994  198.410004  200.020004  197.661011
# ...                ...         ...         ...         ...         ...
# 2019-12-18  364.000000  372.380005  362.269989  366.529999  366.529999
# 2019-12-19  365.000000  368.790009  358.519989  360.059998  360.059998
# 2019-12-20  360.700012  365.000000  357.570007  364.839996  364.839996
# 2019-12-23  364.410004  365.320007  353.019989  353.630005  353.630005
# 2019-12-24  353.250000  362.170013  351.279999  361.779999  361.779999
#
#               Volume
# 2019-01-07  27316700
# 2019-01-08  16935200
# 2019-01-09  11362000
# 2019-01-10  17265500
# ...

# %%
# %matplotlib inline
df.Close.plot()

# %%
df.asfreq('M',method='pad')
df.head(10)
# Out:
#                   Open        High         Low       Close   Adj Close  \
# 2019-01-07  203.169998  204.490005  200.649994  201.550003  199.172989
# 2019-01-08  201.410004  203.130005  201.360001  202.729996  200.339050
# 2019-01-09  203.279999  204.440002  202.690002  204.410004  201.999237
# 2019-01-10  203.350006  205.080002  202.899994  204.229996  201.821350
# 2019-01-11  200.809998  201.399994  198.410004  200.020004  197.661011
# 2019-01-14  199.199997  201.509995  198.809998  201.240005  198.866638
# 2019-01-15  201.850006  203.729996  201.559998  203.229996  200.833160
# 2019-01-16  203.309998  204.389999  201.710007  201.750000  199.370621
# 2019-01-17  202.449997  204.000000  202.199997  203.300003  200.902344
# 2019-01-18  204.089996  205.869995  204.000000  205.210007  202.789810
#
#               Volume
# 2019-01-07  27316700
# 2019-01-08  16935200
# 2019-01-09  11362000
# 2019-01-10  17265500
# 2019-01-11  25338600
# 2019-01-14  20578000
# 2019-01-15  17897100
# ...

# %%
rng = pd.date_range(start = "1/2/2019" ,periods=72,freq='M')
rng
# Out:
# DatetimeIndex(['2019-01-31', '2019-02-28', '2019-03-31', '2019-04-30',
#                '2019-05-31', '2019-06-30', '2019-07-31', '2019-08-31',
#                '2019-09-30', '2019-10-31', '2019-11-30', '2019-12-31',
#                '2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31', '2020-11-30', '2020-12-31',
#                '2021-01-31', '2021-02-28', '2021-03-31', '2021-04-30',
#                '2021-05-31', '2021-06-30', '2021-07-31', '2021-08-31',
#                '2021-09-30', '2021-10-31', '2021-11-30', '2021-12-31',
#                '2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31',
#                '2023-01-31', '2023-02-28', '2023-03-31', '2023-04-30',
# ...

# %%
import numpy as np
ts = pd.Series(np.random.randint(1,10,len(rng)),index=rng)
ts.head()
# Out:
# 2019-01-31    5
# 2019-02-28    2
# 2019-03-31    6
# 2019-04-30    8
# 2019-05-31    2
# Freq: M, dtype: int32
